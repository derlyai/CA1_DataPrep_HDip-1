# %%
# import Librerias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the dataset
df = pd.read_csv('student_data.csv')

# Show first 5 records
df.head()
# Out:
#   Marital status  Application mode  Application order  Course  \
# 0              1                17                  5   171.0
# 1              1                15                  1  9254.0
# 2              1                 1                  5  9070.0
# 3              1                17                  2  9773.0
# 4              2                39                  1  8014.0
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
# Categorical and numerical variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   object
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4423 non-null   float64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
# Renaming
df=df.rename(columns={'Daytime/evening attendance': 'Daytime','Previous qualification (grade)':'Previous grade',
                      'Educational special needs':'Educational','Tuition fees up to date':'Tuition fees',
                     'Scholarship holder':'Scholarship','Age at enrollment':'Age','Curricular units 1st sem (credited)':'Curricular credited',
                     'Curricular units 1st sem (enrolled)':'Curricular enrolled','Curricular units 1st sem (evaluations)':'Curricular evaluations',
                     'Curricular units 1st sem (approved)':'Curricular approved','Curricular units 1st sem (grade)':'Curricular grade',
                     'Curricular units 1st sem (without evaluations)':'Curricular without evalu','Curricular units 2nd sem (credited)':'Curricular 2 credited',
                     'Curricular units 2nd sem (enrolled)':'Curricular 2 enrolled','Curricular units 2nd sem (evaluations)':'Curricular 2 evalu',
                     'Curricular units 2nd sem (approved)': 'Curricular 2 approved','Curricular units 2nd sem (grade)':'Curricular 2 grade',
                    'Curricular units 2nd sem (without evaluations)':'Curricular 2 without evalu'})

# %%
# Fields that have null values
df.isnull().sum()
# Out:
# Marital status                0
# Application mode              0
# Application order             0
# Course                        1
# Daytime                       0
# Previous qualification        0
# Previous grade                0
# Nacionality                   0
# Mother's qualification        0
# Father's qualification        1
# Mother's occupation           0
# Father's occupation           0
# Admission grade               1
# Displaced                     0
# Educational                   0
# Debtor                        1
# Tuition fees                  1
# Gender                        0
# Scholarship                   0
# Age                           0
# International                 1
# Curricular credited           0
# Curricular enrolled           0
# Curricular evaluations        0
# Curricular approved           0
# Curricular grade              1
# Curricular without evalu      0
# Curricular 2 credited         0
# Curricular 2 enrolled         1
# ...

# %%
# Remove unknown values
missing_value_formats = ["n.a.","?","NA","n/a", "Na", "na", "nan", "--", "UnKnown"]
df = pd.read_csv('student_data.csv', na_values = missing_value_formats)

# %%
import numpy as np
convert_dict={"Marital status":np.dtype(int)}
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4423 non-null   float64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4423 non-null   float64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
# Because there was so little missing data, I chose to delete the corresponding rows
df.dropna(inplace=True)

# %%
df['Target'].unique()
# Out:
# array(['Dropout', 'Graduate', 'Enrolled', 'Grad', 'graduate', 'Drop',
#        'dropout'], dtype=object)

# %%
df['Target'].replace({'Grad': 'Graduate', 'graduate': 'Graduate', 'Drop': 'Dropout', 'dropout': 'Dropout'}, inplace = True)

# %%
df['Target'].replace({'Graduate': 1, 'Dropout': 0, 'Enrolled': 2 }, inplace = True)

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4411.000000       4411.000000        4411.000000  4411.000000
# mean         1.178644         18.671276           1.728406  8861.600091
# std          0.606321         17.470528           1.313857  2053.895552
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         53.000000           9.000000  9991.000000
#
#        Daytime/evening attendance  Previous qualification  \
# count                 4411.000000             4411.000000
# mean                     0.890954                4.585355
# std                      0.311732               10.228951
# min                      0.000000                1.000000
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (4411, 37)

# %%
import matplotlib.pyplot as plt 
plt.boxplot(df)
plt.title("Boxplot de Datos")
plt.xlabel("Variable X")
plt.ylabel("Valores")
plt.show()

# %%
wine_no_label = wine_df.drop(wine_df["Marital status"])
pca = PCA().fit(wine_no_label) 
plt.plot(np.cumsum(pca.explained_variance_ratio_)) 
plt.xlabel('Unemployment rate') 
plt.ylabel('Target');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 wine_no_label = wine_df.drop(wine_df["Marital status"])
#       2 pca = PCA().fit(wine_no_label)
#       3 plt.plot(np.cumsum(pca.explained_variance_ratio_))
#
# NameError: name 'wine_df' is not defined
