# %%
# import Librerias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the dataset
df = pd.read_csv('student_data.csv')

# Show first 5 records
df.head()
# Out:
#   Marital status  Application mode  Application order  Course  \
# 0              1                17                  5   171.0
# 1              1                15                  1  9254.0
# 2              1                 1                  5  9070.0
# 3              1                17                  2  9773.0
# 4              2                39                  1  8014.0
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
# Categorical and numerical variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   object
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4423 non-null   float64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
# Fields that have null values
df.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            1
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            1
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   1
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            1
# Tuition fees up to date                           1
# Gender                                            0
# ...

# %%
# Because there was so little missing data, I chose to delete the corresponding rows
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4415 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4415 non-null   object
#  1   Application mode                                4415 non-null   int64
#  2   Application order                               4415 non-null   int64
#  3   Course                                          4415 non-null   float64
#  4   Daytime/evening attendance                      4415 non-null   int64
#  5   Previous qualification                          4415 non-null   int64
#  6   Previous qualification (grade)                  4415 non-null   float64
#  7   Nacionality                                     4415 non-null   int64
#  8   Mother's qualification                          4415 non-null   int64
# ...

# %%
# Remove unknown values
rows_with_question_mark = df[df.apply(lambda x: x.astype(str).str.contains('\?').any(), axis=1)]
rows_with_question_mark
# Out:
#      Marital status  Application mode  Application order  Course  \
# 154               ?                43                  1  9853.0
# 468               1                 1                  5  9500.0
# 4089              2                43                  1  8014.0
#
#       Daytime/evening attendance  Previous qualification  \
# 154                            1                       1
# 468                            1                       1
# 4089                           0                      14
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 154                            115.0            1                       3
# 468                            144.0            1                      19
# 4089                           133.1            1                      34
#
#       Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 154                     37.0  ...                                    0
# ...

# %%
df=df.rename(columns={"Daytime/evening attendance": "Daytime","Previous qualification (grade)":"Previous grade",
                      "Educational special needs":"Educational special","Tuition fees up to date":"Tuition fees",
                      "Scholarship holder":"Scholarship","Curricular units 1st sem (credited)":"Curricular credited",
                      "Curricular units 1st sem (enrolled)":"Curricular enrolled"})

# %%
* PENDIENTE CAMBIAR NOMBRES
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4412 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4412 non-null   object
#  1   Application mode                                4412 non-null   int64
#  2   Application order                               4412 non-null   int64
#  3   Course                                          4412 non-null   float64
#  4   Daytime                                         4412 non-null   int64
#  5   Previous qualification                          4412 non-null   int64
#  6   Previous grade                                  4412 non-null   float64
#  7   Nacionality                                     4412 non-null   int64
#  8   Mother's qualification                          4412 non-null   int64
# ...
